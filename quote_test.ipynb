# %% [markdown]
# ### This notebook is the test document for seeing if I can set up a process for inspecting n-grams and matching them to other n-grams in the text.
#
# The general idea here would be to use a sliding window of length n over the text. For every n-gram, it should look back for older chronological n-grams and identify matches, which will be considered a "quote". Once quotes are identified, we will need to sift through the quotes and pick out the ones that are meaningful.

# %%
import pandas as pd
